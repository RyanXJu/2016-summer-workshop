# %% [markdown]
# <a href="https://colab.research.google.com/github/RyanXJu/2016-summer-workshop/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from statistics import mean

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# load listing datasets
data = pd.read_excel("/AgeGroup_cleaned.xlsx", header=0, index_col=0)
data.shape
data.head()
# Out:
#                                                2015_LF  ...  MAR2020_EP_55
# All industries                                 19278.0  ...         3968.7
# Real estate and rental and leasing               322.1  ...          112.9
# Manufacturing                                   1798.1  ...          403.1
# Mining, quarrying, and oil and gas extraction    317.9  ...           40.1
# Construction                                    1504.9  ...          284.4
#
# [5 rows x 40 columns]

# %%
lf_all = data.iloc[:,0:10]
lf_all.columns = ["2015","2016", "2017", "2018", "2019","Nov2019", "Dec2019", "Jan2020", "Feb2020", "Mar2020"]
lf_all.head()
# Out:
#                                                   2015  ...  Mar2020
# All industries                                 19278.0  ...  19499.4
# Real estate and rental and leasing               322.1  ...    349.4
# Manufacturing                                   1798.1  ...   1762.0
# Mining, quarrying, and oil and gas extraction    317.9  ...    265.0
# Construction                                    1504.9  ...   1522.2
#
# [5 rows x 10 columns]

# %%
lf_55 = data.iloc[:, 10:20]
lf_55.columns = ["2015","2016", "2017", "2018", "2019","Nov2019", "Dec2019", "Jan2020", "Feb2020", "Mar2020"]

# %%
plt.figure()
for i in range(1,lf_all.shape[1]):
    plt.plot(lf_all.iloc[i][5:9]/lf_all.iloc[i][5], label = lf_all.index.values[i] )#, label = LF_all.index.values[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
lf_all.index.values[1]
# Out:
# 'Real estate and rental and leasing'

# %%
ep_all = data.iloc[:,20:30]
ep_all.columns = ["2015","2016", "2017", "2018", "2019","Nov2019", "Dec2019", "Jan2020", "Feb2020", "Mar2020"]
ep_all.head()
# Out:
#                                                   2015  ...  Mar2020
# All industries                                 17946.6  ...  17856.6
# Real estate and rental and leasing               311.9  ...    335.0
# Manufacturing                                   1712.4  ...   1665.0
# Mining, quarrying, and oil and gas extraction    289.9  ...    250.4
# Construction                                    1371.2  ...   1368.7
#
# [5 rows x 10 columns]

# %%
# # plt.figure()
# # for i in range(1,ep_all.shape[1]):
# #     dif = (ep_all.iloc[i][9]-ep_all.iloc[i][5])
# #     plt.hist( dif/ep_all.iloc[i][5], label = ep_all.index.values[i] )#, label = LF_all.index.values[i])
# # plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# # plt.show()

# dif = (ep_all.loc[:,"Mar2020"]-ep_all.loc[:,"Nov2019"])/ep_all.loc[:,"Nov2019"]
# dif = dif.fillna(0)
# dif

# import seaborn.apionly as sns
# import matplotlib.pyplot as plt

# x = ep_55.index
# y = dif

# pairs = zip(x, y)
# pairs= sorted(pairs, key=lambda x: x[1], reverse= True)

# newx, newy = zip(*pairs)
# ax = sns.barplot(x=newx, y=newy)

# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-209-299f5e808497> in <module>()
#      14
#      15 newx, newy = zip(*pairs)
# ---> 16 ax = sns.barplot(x=newx, y=newy)
#      17
#      18 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ...

# %%
x
# Out:
# Index(['All industries', 'Real estate and rental and leasing', 'Manufacturing',
#        'Mining, quarrying, and oil and gas extraction', 'Construction',
#        'Health care and social assistance', 'Public Administration',
#        'Finance and Insurance',
#        'Professional, scientific and technical services', 'Wholesale Trade',
#        'Educational Services', 'Retail Trade',
#        'Transportation and warehousing', 'Information and cultural industries',
#        'Administrative and support, waste management and remediation services',
#        'Accommodation and food services', 'Utilities',
#        'Agriculture, forestry, fishing and hunting',
#        'Other services (except public administration)',
#        'Arts, entertainment and recreation',
#        'Management of companies and enterprises'],
#       dtype='object')

# %%
ep_55.index
# Out:
# Index(['All industries', 'Real estate and rental and leasing', 'Manufacturing',
#        'Mining, quarrying, and oil and gas extraction', 'Construction',
#        'Health care and social assistance', 'Public Administration',
#        'Finance and Insurance',
#        'Professional, scientific and technical services', 'Wholesale Trade',
#        'Educational Services', 'Retail Trade',
#        'Transportation and warehousing', 'Information and cultural industries',
#        'Administrative and support, waste management and remediation services',
#        'Accommodation and food services', 'Utilities',
#        'Agriculture, forestry, fishing and hunting',
#        'Other services (except public administration)',
#        'Arts, entertainment and recreation',
#        'Management of companies and enterprises'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-7dfce8bcafb4> in <module>()
# ----> 1 dif[:,1]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     908             key = check_bool_indexer(self.index, key)
#     909
# --> 910         return self._get_with(key)
#     911
#     912     def _get_with(self, key):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in _get_with(self, key)
#     921         elif isinstance(key, tuple):
#     922             try:
# --> 923                 return self._get_values_tuple(key)
#     924             except ValueError:
#     925                 # if we don't have a MultiIndex, we may still be able to handle
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in _get_values_tuple(self, key)
#     972
# ...

# %%
ep_55 = data.iloc[:,30:40]
ep_55.columns = ["2015","2016", "2017", "2018", "2019","Nov2019", "Dec2019", "Jan2020", "Feb2020", "Mar2020"]
ep_55.head()
# Out:
#                                                  2015    2016  ...  Feb2020  Mar2020
# All industries                                 3602.5  3748.7  ...   4174.1   3968.7
# Real estate and rental and leasing               95.8   105.9  ...    114.8    112.9
# Manufacturing                                   373.0   389.2  ...    409.4    403.1
# Mining, quarrying, and oil and gas extraction    47.5    40.8  ...     39.3     40.1
# Construction                                    245.1   252.2  ...    287.1    284.4
#
# [5 rows x 10 columns]

# %%
for i in range(10):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 3))
    fig.suptitle(ep_55.index.values[i], fontweight='bold')
    axes[0].plot(ep_55.iloc[i], label = ep_55.index.values[i], color = "red")
    axes[1].plot(ep_young.iloc[i], label = ep_young.index.values[i])
    axes[0].tick_params(labelrotation=45)
    axes[1].tick_params(labelrotation=45)
    axes[0].set_xlabel('55+ years')
    axes[1].set_xlabel('15 to 54 years')

    plt.show()


# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5, 3))
# axes[0].plot(x1, y1)
# axes[1].plot(x2, y2)
# fig.tight_layout()

# %%
ep_young = ep_all - ep_55
ep_young
lf_young = lf_all - lf_55

for i in range(10):
    plt.plot(ep_55.iloc[i], label = "over 55")
    plt.plot(ep_young.iloc[i], label = "15 to 54")
    plt.plot(lf_55.iloc[i], label = "over 55")
    plt.plot(lf_young.iloc[i], label = "15 to 54")
    plt.title(ep_55.index.values[i])
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()
